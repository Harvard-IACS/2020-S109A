# %% [markdown]
# # <img style="float: left; padding-right: 10px; width: 45px" src="https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/iacs.png"> CS-109A Introduction to Data Science

# %% [markdown]
# ## Lab X: Review and Random Topics
#
# **Harvard University**<br/>
# **Fall 2019**<br/>
# **Authors:** Rylan Schaeffer
#
# ---

# %%
## RUN THIS CELL TO GET THE RIGHT FORMATTING 
import requests
from IPython.core.display import HTML
styles = requests.get("https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/cs109.css").text
HTML(styles)
# Out:
# <style>
# blockquote { background: #AEDE94; }
# h1 {
#     padding-top: 25px;
#     padding-bottom: 25px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #DDDDDD;
#     color: black;
# }
# h2 {
#     padding-top: 10px;
#     padding-bottom: 10px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
#
# div.exercise {
# 	background-color: #ffcccc;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# }
#
# span.sub-q {
# 	font-weight: bold;
# }
# div.theme {
# 	background-color: #DDDDDD;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# 	font-size: 18pt;
# }
# div.gc {
# 	background-color: #AEDE94;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# 	font-size: 12pt;
# }
# p.q1 {
#     padding-top: 5px;
#     padding-bottom: 5px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
# header {
#    padding-top: 35px;
#     padding-bottom: 35px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #DDDDDD;
#     color: black;
# }
# </style>

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

print(tf.__version__)  # You should see a 2.0.0 here!
# Out:
# 2.0.0

# %% [markdown]
# ## Table of Contents
# <ol start="0">
#     <li>Reminder: Code Effectively!</li>
#     <li>Rylan's Summary of the Course</li>
#     <li>Concepts to Clarify</li>
#     <li>Neural Networks</li>
#     <li>Rylan's Experience as a Data Scientist at Uber</li>
# </ol>

# %% [markdown]
# ## Reminder: Code Effectively
#
#
# - When debugging, **read the error message** at the bottom and work your way up
#     - Error messages can sometimes be difficult to interpret for a beginner
#     - But error messages tells you exactly what failed and why. From this, you can work backwards
#
# - Use keyboard shortcuts.
#     - Help you move faster, spend less energy on slow aspects
#     - If you can't remember them, go to the top "Help" then "Keyboard Shortcuts"
#     - Some of my favorites:
#         - Add cell above: a
#         - Add cell below: b
#         - Delete current cell: dd
#         - Autocomplete code: tab
#         - Show documentation for a function: shift + tab
#         - Change cell to Markdown: m
#         - Change cell to Code: y
#     - If you use an IDE (RStudio, PyCharm, Spyder, etc) or a web browser (Firefox, Chrome, Safari, IE), those have keyboard shortcuts too
#
# - Don't place large blocks of code in single cell/function. Use cells/functions liberally!
#     - Makes debugging & rerunning much easier!
#
# **Saving a second may seem unimportant, but if you sum those seconds up, you'll get back significant time on your life**

# %% [markdown]
# ## Rylan's Summary of the Course

# %% [markdown]
# In this class, we've covered linear regression, logistic regression, classification and regression trees, bagging, boosting, random forests, neural networks, cross validation, regularization (e.g. LASSO, ridge), PCA and more! How do they all fit together?
#
# In general, one central goal of data science is to relate different random variables to one another. For example, in classification, we might want to predict the likely class (e.g. obesity) for specific predictors (e.g. height and weight). A mathematical relationship between variables is a model, and we've seen several of these:
#
# Models:
#     - Linear Regression
#     - Logistic Regression
#     - Classification/Regression Trees
#     - Neural Networks
#
# These models are mathematical relationships between random variables. For instance, linear regression posits that some variable $y$ is a linear transformation of input features $x$:
#
# \begin{align*}
#   \hat{y} = \beta_0 + \beta_1 x_1 + \beta_2 x_2 + ... + \beta_n x_n
# \end{align*}
#
# One central problem is that if our model is too "simple" then it will miss out on useful signals (underfit), but that if our model is too "complex" then it will pick up on training-data specific signals (overfit).

# %% [markdown]
# ![](../img/train_test_error.png)

# %% [markdown]
# ### How do we find the Goldilocks zone of the best fit?
#
# Two general approaches
#
#     1. Start with complex models and limit their complexity
#     2. Start with simple models and add complexity

# %% [markdown]
# ### Approach 1: Start complex, go simple
#
#     - Use a single model but give it a resource budget
#         - Penalize the sum of fit parameters squared (e.g. regression with Ridge regularization)
#         - Penalize the sum of absolute value of fit parameters (e.g. regression with LASSO regularization)
#     - Measure how well a model performs on non-training data
#         - Fit a model multiple times on different subsets of training data (e.g. K-fold Cross Validation)
#     - Ensemble many models, but hamstring each model
#         - Each model sees all features but only a subset of data points (e.g. bagging with trees)
#         - Each model sees only a subset of features but all data points (e.g. random forest)
#     - These are not mutually exclusive! We can use cross validation to determine hyperparameters
#
# ### Approach 2: Start simple, go complex
#
#     - Iteratively fit simple models, correcting for the mistakes of the previous models (e.g. boosting)
#     - Ensemble many models, but hamstring each model (different view)

# %% [markdown]
# ### Other benefits (e.g. Feature Importance)
#
# These techniques also provide other benefits! For instance, suppose we want to know which features are most important. If we give a single model a resource budget (e.g. linear regression with ridge regularization) or if we give many models only a subset of data points (bagging with trees), we can ask which features are prioritized by the single model or by the ensemble of models. This information can be used to make better models or improve understanding of the data being studied.

# %% [markdown]
# ## Concepts to Clarify

# %% [markdown]
# ### Never use test data to fit models or choose hyperparameters
#
# Test data provides a final estimate of how well your model will generalize. Choosing your model or its hyperparameters using test data defeats the purpose of separating training data from testing data!

# %% [markdown]
# ### Based on the number of samples and number of features, is there a rule of thumb how choose the right model and the right complexity, or is the answer solely experimental?
#
# Both. There are settings in which certain models will do well (and do poorly), and when you recognize that you're in such a setting, you should leverage that knowledge to choose the right model. But in general, you will not know and the answer will be largely empiric.
#
# Three classification examples from [sklearn](https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html):

# %% [markdown]
# ![](../img/classifier_comparison.png)

# %% [markdown]
# #### Concept Check: For each of the above three datasets, how would you expect logistic regression to perform?

# %% [markdown]
# ### What is the difference between LASSO and Ridge regularization, specifically regarding variable selection?
#
# Both are techniques to penalize model complexity by giving the model a limit budget over the input features. Mathematically, this takes the form of a penalty term in the loss function that depends on the parameters of the model.
#
#
# For example, in linear regression, we wanted to find parameters $\boldsymbol{\beta}$ that minimizes the following error:
#
# \begin{align*}
#   L(\boldsymbol{\beta}) = \frac{1}{n} \sum_{i=1}^n \|y_i - \boldsymbol{\beta}^T \mathbf{x}_i\|^2.
# \end{align*}
#
# In linear regression with ridge regularization, we penalize the sum of the squares of the parameters:
#
# \begin{align*}
#   L_{\text{ridge}}(\boldsymbol{\beta}) = \frac{1}{n} \sum_{i=1}^n \|y_i - \boldsymbol{\beta}^T \mathbf{x}_i\|^2 + \lambda \sum_{j=1}^m \beta_{j}^{2}.
# \end{align*}
#
# In linear regression with LASSO regularization, we penalize the sum of the absolute values of the parameters:
#
# \begin{align*}
#   L_{\text{LASSO}}(\boldsymbol{\beta}) = \frac{1}{n} \sum_{i=1}^n \|y_i - \boldsymbol{\beta}^T \mathbf{x}_i\|^2 + \lambda \sum_{j=1}^m |\beta_j|.
# \end{align*}
#
# **But how do these two regularization approaches actually differ in terms of the parameters?**
#
# ![](../img/ridge_lasso_regularization.png)
#
# LASSO regularization will find sparser parameters (i.e. more parameters will be set to 0) than Ridge regularization.

# %% [markdown]
# ### What is the curse of dimensionality? Why is it a curse?
#
# The curse of dimensionality refers to the property that as the number of your features increases, the density of your data typically increases much more slowly than the total volume of the dimensionality. This means your data becomes incredibly sparse and model fitting becomes hard.
#
# Aside: Human intution acquired from living in a low dimensional world is woefully inadequate for understanding high dimensions. Strange phenomena can occur that are perfectly reasonable in 100 dimensions that are nonsensical in 3 dimensions.

# %% [markdown]
# ### What is the bias-variance tradeoff? Why does such a tradeoff necessarily exist?
#
# Intution: from [Andrew Gelman, Professor of Statistics, Director of Applied Statistics Center at Columbia University](https://statmodeling.stat.columbia.edu/2011/10/15/the-bias-variance-tradeoff/):
#
# "The basic idea is as follows: if you’re estimating something, you can slice your data finer and finer, or perform more and more adjustments, each time getting a purer—and less biased—estimate. But each subdivision or each adjustment reduces your sample size or increases potential estimation error, hence the variance of your estimate goes up.
#
# That story is real. In lots and lots of examples, there’s a continuum between a completely unadjusted general estimate (high bias, low variance) and a specific, focused, adjusted estimate (low bias, high variance).
#
# Suppose, for example, you’re using data from a large experiment to estimate the effect of a treatment on a fairly narrow group, say, white men between the ages of 45 and 50. At one extreme, you could just take the estimated treatment effect for the entire population, which could have high bias (to the extent the effect varies by age, sex, and ethnicity) but low variance (because you’re using all the data). At the other extreme, you could form an estimate using only data from the group in question, which would then be unbiased (assuming an appropriate experimental design) but would have a high variance."

# %% [markdown]
# ### How can trees be used for classification and regression (at the same time)?
#
# As far as I know, trees typically aren't used for both *simultaneously*. However, trees can certainly be used for classification and regression separately. How do the two settings differ? They are both the same in that trees carve the feature space up using a splitting criterion (e.g. cross entropy for classification, variance reduction for regression) and then at each leaf, a simple model is fit. For `sklearn.tree.DecisionTreeRegressor`, the simple model is the mean of training data that falls into that particular leaf:
#
# See [sklearn documentation](https://scikit-learn.org/stable/modules/tree.html)
#
# ![](../img/regression_tree.png)

# %% [markdown]
# ## Neural Networks

# %% [markdown]
# What is a neural network? There are many different viewpoints. One viewpoint is the neuroscience-inspired pictoral representation:
#
# ![](../img/neural_network.png)
#
#
# A slightly more mathematical viewpoint is that a neural network is a **composite** (i.e. sequence of chained functions), **parametric** (i.e. having parameters) function comprised of two types of **repeating**, **alternating** functions:
#     1. Affine transformation:
#
# $$h_l = W_l x_{l-1} + b_l$$
#
#     2. Element-wise nonlinearities
#
# $$x_l = \sigma (h_l) = \frac{1}{1 + e^{-h_l}}$$
#
# Here, $l$ denotes the layer with $L$ total layers. We say that the neural network is a parametric function because it depends on all the parameters $\{W_1, b_1, W_2, b_2, ..., W_L, b_L \}$.
#
#
# To see why this is a **composite** function, let's explicitly write out the sequence of chained functions:
#
#
# \begin{align*}
# \hat{y} &= NN(x)\\
# &= \underbrace{W_L \underbrace{\sigma(W_{L-1} \sigma (\underbrace{... \underbrace{\sigma(W_2 \underbrace{\sigma(W_1 x + b_1)}_{\text{1st layer}} + b_2)}_{\text{2nd layer}} + ...)}_{\vdots} + b_{L-1})}_{\text{L-1 layer}} + b_L}_{\text{L layer}}
# \end{align*}

# %% [markdown]
# Let's do some exercises! Suppose we want to predict $y$ given $x$, where the data is generated via $y = x \sin x$:

# %%
batch_size = 100
x = np.linspace(0, 7, batch_size)
x_in_batch_form = x.reshape(batch_size, 1)
print('x_in_batch_form shape: ', x_in_batch_form.shape)
y = np.multiply(x, np.sin(x))
plt.plot(x, y)
# Out:
# x_in_batch_form shape:  (100, 1)

# %% [markdown]
# #### Exercise 1: Suppose we fit a single layer neural network (i.e. no hidden layers) with no non-linear activation function. What will our model learn?

# %%
# create a single layer neural network with no activation function

single_layer_linear_network = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1, input_shape=(1,)),
])
single_layer_linear_network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the neural network

single_layer_linear_network.compile(optimizer='sgd', loss=tf.keras.losses.MeanSquaredError())
single_layer_linear_network.fit(x_in_batch_form, y, epochs=100, batch_size=batch_size)
# Out:
# Train on 100 samples
# Epoch 1/100
# 100/100 [==============================] - 0s 3ms/sample - loss: 19.0045
# Epoch 2/100
# 100/100 [==============================] - 0s 10us/sample - loss: 11.3242
# Epoch 3/100
# 100/100 [==============================] - 0s 14us/sample - loss: 8.0133
# Epoch 4/100
# 100/100 [==============================] - 0s 16us/sample - loss: 6.5858
# Epoch 5/100
# 100/100 [==============================] - 0s 14us/sample - loss: 5.9701
# Epoch 6/100
# 100/100 [==============================] - 0s 12us/sample - loss: 5.7043
# Epoch 7/100
# 100/100 [==============================] - 0s 13us/sample - loss: 5.5893
# Epoch 8/100
# 100/100 [==============================] - 0s 10us/sample - loss: 5.5394
# Epoch 9/100
# 100/100 [==============================] - 0s 14us/sample - loss: 5.5175
# Epoch 10/100
# 100/100 [==============================] - 0s 32us/sample - loss: 5.5076
# Epoch 11/100
# 100/100 [==============================] - 0s 25us/sample - loss: 5.5030
# Epoch 12/100
# 100/100 [==============================] - 0s 27us/sample - loss: 5.5006
# Epoch 13/100
# 100/100 [==============================] - 0s 20us/sample - loss: 5.4992
# Epoch 14/100
# 100/100 [==============================] - 0s 13us/sample - loss: 5.4983
# Epoch 15/100
# 100/100 [==============================] - 0s 18us/sample - loss: 5.4975
# Epoch 16/100
# 100/100 [==============================] - 0s 29us/sample - loss: 5.4968
# Epoch 17/100
# 100/100 [==============================] - 0s 21us/sample - loss: 5.4961
# Epoch 18/100
# 100/100 [==============================] - 0s 31us/sample - loss: 5.4955
# Epoch 19/100
# 100/100 [==============================] - 0s 23us/sample - loss: 5.4949
# Epoch 20/100
# 100/100 [==============================] - 0s 14us/sample - loss: 5.4942
# Epoch 21/100
# 100/100 [==============================] - 0s 13us/sample - loss: 5.4936
# Epoch 22/100
# 100/100 [==============================] - 0s 17us/sample - loss: 5.4930
# Epoch 23/100
# 100/100 [==============================] - 0s 20us/sample - loss: 5.4924
# Epoch 24/100
# 100/100 [==============================] - 0s 22us/sample - loss: 5.4918
# Epoch 25/100
# 100/100 [==============================] - 0s 15us/sample - loss: 5.4912
# Epoch 26/100
# 100/100 [==============================] - 0s 21us/sample - loss: 5.4907
# Epoch 27/100
# 100/100 [==============================] - 0s 26us/sample - loss: 5.4901
# Epoch 28/100
# 100/100 [==============================] - 0s 22us/sample - loss: 5.4895
# Epoch 29/100
# 100/100 [==============================] - 0s 42us/sample - loss: 5.4889
# Epoch 30/100
# 100/100 [==============================] - 0s 23us/sample - loss: 5.4884
# Epoch 31/100
# 100/100 [==============================] - 0s 23us/sample - loss: 5.4878
# Epoch 32/100
# 100/100 [==============================] - 0s 18us/sample - loss: 5.4873
# Epoch 33/100
# 100/100 [==============================] - 0s 18us/sample - loss: 5.4867
# Epoch 34/100
# 100/100 [==============================] - 0s 13us/sample - loss: 5.4862
# Epoch 35/100
# 100/100 [==============================] - 0s 15us/sample - loss: 5.4857
# Epoch 36/100
# 100/100 [==============================] - 0s 16us/sample - loss: 5.4851
# Epoch 37/100
# 100/100 [==============================] - 0s 26us/sample - loss: 5.4846
# Epoch 38/100
# 100/100 [==============================] - 0s 34us/sample - loss: 5.4841
# Epoch 39/100
# 100/100 [==============================] - 0s 38us/sample - loss: 5.4836
# Epoch 40/100
# 100/100 [==============================] - 0s 51us/sample - loss: 5.4831
# Epoch 41/100
# 100/100 [==============================] - 0s 26us/sample - loss: 5.4826
# Epoch 42/100
# 100/100 [==============================] - 0s 22us/sample - loss: 5.4821
# Epoch 43/100
# 100/100 [==============================] - 0s 31us/sample - loss: 5.4816
# Epoch 44/100
# 100/100 [==============================] - 0s 30us/sample - loss: 5.4811
# Epoch 45/100
# 100/100 [==============================] - 0s 34us/sample - loss: 5.4806
# Epoch 46/100
# 100/100 [==============================] - 0s 25us/sample - loss: 5.4801
# Epoch 47/100
# 100/100 [==============================] - 0s 25us/sample - loss: 5.4796
# Epoch 48/100
# 100/100 [==============================] - 0s 26us/sample - loss: 5.4792
# Epoch 49/100
# 100/100 [==============================] - 0s 33us/sample - loss: 5.4787
# Epoch 50/100
# 100/100 [==============================] - 0s 48us/sample - loss: 5.4782
# Epoch 51/100
# 100/100 [==============================] - 0s 41us/sample - loss: 5.4778
# Epoch 52/100
# 100/100 [==============================] - 0s 32us/sample - loss: 5.4773
# Epoch 53/100
# 100/100 [==============================] - 0s 25us/sample - loss: 5.4769
# Epoch 54/100
# 100/100 [==============================] - 0s 22us/sample - loss: 5.4764
# Epoch 55/100
# 100/100 [==============================] - 0s 21us/sample - loss: 5.4760
# Epoch 56/100
# 100/100 [==============================] - 0s 25us/sample - loss: 5.4756
# Epoch 57/100
# 100/100 [==============================] - 0s 26us/sample - loss: 5.4751
# Epoch 58/100
# 100/100 [==============================] - 0s 36us/sample - loss: 5.4747
# Epoch 59/100
# 100/100 [==============================] - 0s 40us/sample - loss: 5.4743
# Epoch 60/100
# 100/100 [==============================] - 0s 19us/sample - loss: 5.4739
# Epoch 61/100
# 100/100 [==============================] - 0s 35us/sample - loss: 5.4735
# Epoch 62/100
# 100/100 [==============================] - 0s 31us/sample - loss: 5.4731
# Epoch 63/100
# 100/100 [==============================] - 0s 35us/sample - loss: 5.4726
# Epoch 64/100
# 100/100 [==============================] - 0s 23us/sample - loss: 5.4722
# Epoch 65/100
# 100/100 [==============================] - 0s 44us/sample - loss: 5.4718
# Epoch 66/100
# 100/100 [==============================] - 0s 38us/sample - loss: 5.4714
# Epoch 67/100
# 100/100 [==============================] - 0s 33us/sample - loss: 5.4711
# Epoch 68/100
# 100/100 [==============================] - 0s 29us/sample - loss: 5.4707
# Epoch 69/100
# 100/100 [==============================] - 0s 24us/sample - loss: 5.4703
# Epoch 70/100
# 100/100 [==============================] - 0s 46us/sample - loss: 5.4699
# Epoch 71/100
# 100/100 [==============================] - 0s 33us/sample - loss: 5.4695
# Epoch 72/100
# 100/100 [==============================] - 0s 50us/sample - loss: 5.4692
# Epoch 73/100
# 100/100 [==============================] - 0s 25us/sample - loss: 5.4688
# Epoch 74/100
# 100/100 [==============================] - 0s 21us/sample - loss: 5.4684
# Epoch 75/100
# 100/100 [==============================] - 0s 42us/sample - loss: 5.4681
# Epoch 76/100
# 100/100 [==============================] - 0s 21us/sample - loss: 5.4677
# Epoch 77/100
# 100/100 [==============================] - 0s 54us/sample - loss: 5.4674
# Epoch 78/100
# 100/100 [==============================] - 0s 38us/sample - loss: 5.4670
# Epoch 79/100
# 100/100 [==============================] - 0s 71us/sample - loss: 5.4667
# Epoch 80/100
# 100/100 [==============================] - 0s 25us/sample - loss: 5.4663
# Epoch 81/100
# 100/100 [==============================] - 0s 23us/sample - loss: 5.4660
# Epoch 82/100
# 100/100 [==============================] - 0s 32us/sample - loss: 5.4656
# Epoch 83/100
# 100/100 [==============================] - 0s 51us/sample - loss: 5.4653
# Epoch 84/100
# 100/100 [==============================] - 0s 37us/sample - loss: 5.4650
# Epoch 85/100
# 100/100 [==============================] - 0s 43us/sample - loss: 5.4646
# Epoch 86/100
# 100/100 [==============================] - 0s 25us/sample - loss: 5.4643
# Epoch 87/100
# 100/100 [==============================] - 0s 27us/sample - loss: 5.4640
# Epoch 88/100
# 100/100 [==============================] - 0s 30us/sample - loss: 5.4637
# Epoch 89/100
# 100/100 [==============================] - 0s 54us/sample - loss: 5.4634
# Epoch 90/100
# 100/100 [==============================] - 0s 38us/sample - loss: 5.4630
# Epoch 91/100
# 100/100 [==============================] - 0s 34us/sample - loss: 5.4627
# Epoch 92/100
# 100/100 [==============================] - 0s 35us/sample - loss: 5.4624
# Epoch 93/100
# 100/100 [==============================] - 0s 36us/sample - loss: 5.4621
# Epoch 94/100
# 100/100 [==============================] - 0s 28us/sample - loss: 5.4618
# Epoch 95/100
# 100/100 [==============================] - 0s 27us/sample - loss: 5.4615
# Epoch 96/100
# 100/100 [==============================] - 0s 32us/sample - loss: 5.4612
# Epoch 97/100
# 100/100 [==============================] - 0s 23us/sample - loss: 5.4609
# Epoch 98/100
# 100/100 [==============================] - 0s 27us/sample - loss: 5.4606
# Epoch 99/100
# 100/100 [==============================] - 0s 22us/sample - loss: 5.4604
# Epoch 100/100
# 100/100 [==============================] - 0s 33us/sample - loss: 5.4601

# %%
# plot the neural network's predictions

single_layer_linear_network_yhat = single_layer_linear_network.predict(x_in_batch_form)
plt.plot(x, y, label='Truth')
plt.plot(x, single_layer_linear_network_yhat, label='Single Layer, Linear Network')
plt.legend()

# %% [markdown]
# The key takeaway: a single layer, linear neural network trained under mean squared error is just linear regression! Why is this? Written mathemtically, our prediction is just
#
# $$\hat{y} = Wx + b $$
#
# which is clearly linear regression!

# %% [markdown]
# #### Exercise 2: Suppose we fit a deep neural network (i.e. multiple hidden layers) with no non-linear activation functions. What will our model learn?

# %%
# create a multiple layer neural network with no activation functions

multiple_layer_linear_network = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1, input_shape=(1,)),
    tf.keras.layers.Dense(10),  # arbitrarily chosen, doesn't matter
    tf.keras.layers.Dense(1),
])
multiple_layer_linear_network.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                20
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the neural network

multiple_layer_linear_network.compile(optimizer='sgd', loss=tf.keras.losses.MeanSquaredError())
multiple_layer_linear_network.fit(x_in_batch_form, y, epochs=100, batch_size=batch_size)
# Out:
# Train on 100 samples
# Epoch 1/100
# 100/100 [==============================] - 0s 2ms/sample - loss: 7.7466
# Epoch 2/100
# 100/100 [==============================] - 0s 18us/sample - loss: 6.9209
# Epoch 3/100
# 100/100 [==============================] - 0s 40us/sample - loss: 6.5727
# Epoch 4/100
# 100/100 [==============================] - 0s 49us/sample - loss: 6.3739
# Epoch 5/100
# 100/100 [==============================] - 0s 14us/sample - loss: 6.2412
# Epoch 6/100
# 100/100 [==============================] - 0s 15us/sample - loss: 6.1433
# Epoch 7/100
# 100/100 [==============================] - 0s 14us/sample - loss: 6.0662
# Epoch 8/100
# 100/100 [==============================] - 0s 23us/sample - loss: 6.0029
# Epoch 9/100
# 100/100 [==============================] - 0s 18us/sample - loss: 5.9497
# Epoch 10/100
# 100/100 [==============================] - 0s 18us/sample - loss: 5.9046
# Epoch 11/100
# 100/100 [==============================] - 0s 21us/sample - loss: 5.8664
# Epoch 12/100
# 100/100 [==============================] - 0s 14us/sample - loss: 5.8343
# Epoch 13/100
# 100/100 [==============================] - 0s 12us/sample - loss: 5.8074
# Epoch 14/100
# 100/100 [==============================] - 0s 11us/sample - loss: 5.7851
# Epoch 15/100
# 100/100 [==============================] - 0s 12us/sample - loss: 5.7665
# Epoch 16/100
# 100/100 [==============================] - 0s 22us/sample - loss: 5.7508
# Epoch 17/100
# 100/100 [==============================] - 0s 16us/sample - loss: 5.7373
# Epoch 18/100
# 100/100 [==============================] - 0s 25us/sample - loss: 5.7254
# Epoch 19/100
# 100/100 [==============================] - 0s 17us/sample - loss: 5.7147
# Epoch 20/100
# 100/100 [==============================] - 0s 14us/sample - loss: 5.7049
# Epoch 21/100
# 100/100 [==============================] - 0s 29us/sample - loss: 5.6957
# Epoch 22/100
# 100/100 [==============================] - 0s 28us/sample - loss: 5.6869
# Epoch 23/100
# 100/100 [==============================] - 0s 24us/sample - loss: 5.6785
# Epoch 24/100
# 100/100 [==============================] - 0s 24us/sample - loss: 5.6704
# Epoch 25/100
# 100/100 [==============================] - 0s 23us/sample - loss: 5.6625
# Epoch 26/100
# 100/100 [==============================] - 0s 18us/sample - loss: 5.6549
# Epoch 27/100
# 100/100 [==============================] - 0s 13us/sample - loss: 5.6474
# Epoch 28/100
# 100/100 [==============================] - 0s 15us/sample - loss: 5.6402
# Epoch 29/100
# 100/100 [==============================] - 0s 49us/sample - loss: 5.6332
# Epoch 30/100
# 100/100 [==============================] - 0s 27us/sample - loss: 5.6264
# Epoch 31/100
# 100/100 [==============================] - 0s 40us/sample - loss: 5.6197
# Epoch 32/100
# 100/100 [==============================] - 0s 23us/sample - loss: 5.6133
# Epoch 33/100
# 100/100 [==============================] - 0s 23us/sample - loss: 5.6070
# Epoch 34/100
# 100/100 [==============================] - 0s 24us/sample - loss: 5.6009
# Epoch 35/100
# 100/100 [==============================] - 0s 44us/sample - loss: 5.5950
# Epoch 36/100
# 100/100 [==============================] - 0s 20us/sample - loss: 5.5893
# Epoch 37/100
# 100/100 [==============================] - 0s 22us/sample - loss: 5.5837
# Epoch 38/100
# 100/100 [==============================] - 0s 37us/sample - loss: 5.5783
# Epoch 39/100
# 100/100 [==============================] - 0s 17us/sample - loss: 5.5730
# Epoch 40/100
# 100/100 [==============================] - 0s 20us/sample - loss: 5.5679
# Epoch 41/100
# 100/100 [==============================] - 0s 22us/sample - loss: 5.5630
# Epoch 42/100
# 100/100 [==============================] - 0s 37us/sample - loss: 5.5582
# Epoch 43/100
# 100/100 [==============================] - 0s 18us/sample - loss: 5.5536
# Epoch 44/100
# 100/100 [==============================] - 0s 16us/sample - loss: 5.5491
# Epoch 45/100
# 100/100 [==============================] - 0s 41us/sample - loss: 5.5448
# Epoch 46/100
# 100/100 [==============================] - 0s 29us/sample - loss: 5.5406
# Epoch 47/100
# 100/100 [==============================] - 0s 32us/sample - loss: 5.5365
# Epoch 48/100
# 100/100 [==============================] - 0s 37us/sample - loss: 5.5326
# Epoch 49/100
# 100/100 [==============================] - 0s 22us/sample - loss: 5.5288
# Epoch 50/100
# 100/100 [==============================] - 0s 40us/sample - loss: 5.5251
# Epoch 51/100
# 100/100 [==============================] - 0s 30us/sample - loss: 5.5216
# Epoch 52/100
# 100/100 [==============================] - 0s 36us/sample - loss: 5.5181
# Epoch 53/100
# 100/100 [==============================] - 0s 22us/sample - loss: 5.5148
# Epoch 54/100
# 100/100 [==============================] - 0s 29us/sample - loss: 5.5116
# Epoch 55/100
# 100/100 [==============================] - 0s 24us/sample - loss: 5.5085
# Epoch 56/100
# 100/100 [==============================] - 0s 45us/sample - loss: 5.5055
# Epoch 57/100
# 100/100 [==============================] - 0s 29us/sample - loss: 5.5026
# Epoch 58/100
# 100/100 [==============================] - 0s 30us/sample - loss: 5.4999
# Epoch 59/100
# 100/100 [==============================] - 0s 31us/sample - loss: 5.4972
# Epoch 60/100
# 100/100 [==============================] - 0s 34us/sample - loss: 5.4946
# Epoch 61/100
# 100/100 [==============================] - 0s 41us/sample - loss: 5.4921
# Epoch 62/100
# 100/100 [==============================] - 0s 33us/sample - loss: 5.4897
# Epoch 63/100
# 100/100 [==============================] - 0s 48us/sample - loss: 5.4874
# Epoch 64/100
# 100/100 [==============================] - 0s 68us/sample - loss: 5.4851
# Epoch 65/100
# 100/100 [==============================] - 0s 24us/sample - loss: 5.4830
# Epoch 66/100
# 100/100 [==============================] - 0s 73us/sample - loss: 5.4809
# Epoch 67/100
# 100/100 [==============================] - 0s 34us/sample - loss: 5.4789
# Epoch 68/100
# 100/100 [==============================] - 0s 22us/sample - loss: 5.4770
# Epoch 69/100
# 100/100 [==============================] - 0s 30us/sample - loss: 5.4751
# Epoch 70/100
# 100/100 [==============================] - 0s 44us/sample - loss: 5.4733
# Epoch 71/100
# 100/100 [==============================] - 0s 24us/sample - loss: 5.4716
# Epoch 72/100
# 100/100 [==============================] - 0s 36us/sample - loss: 5.4699
# Epoch 73/100
# 100/100 [==============================] - 0s 29us/sample - loss: 5.4684
# Epoch 74/100
# 100/100 [==============================] - 0s 34us/sample - loss: 5.4668
# Epoch 75/100
# 100/100 [==============================] - 0s 33us/sample - loss: 5.4654
# Epoch 76/100
# 100/100 [==============================] - 0s 65us/sample - loss: 5.4639
# Epoch 77/100
# 100/100 [==============================] - 0s 31us/sample - loss: 5.4626
# Epoch 78/100
# 100/100 [==============================] - 0s 27us/sample - loss: 5.4613
# Epoch 79/100
# 100/100 [==============================] - 0s 19us/sample - loss: 5.4600
# Epoch 80/100
# 100/100 [==============================] - 0s 33us/sample - loss: 5.4588
# Epoch 81/100
# 100/100 [==============================] - 0s 45us/sample - loss: 5.4576
# Epoch 82/100
# 100/100 [==============================] - 0s 28us/sample - loss: 5.4565
# Epoch 83/100
# 100/100 [==============================] - 0s 33us/sample - loss: 5.4555
# Epoch 84/100
# 100/100 [==============================] - 0s 29us/sample - loss: 5.4544
# Epoch 85/100
# 100/100 [==============================] - 0s 21us/sample - loss: 5.4534
# Epoch 86/100
# 100/100 [==============================] - 0s 53us/sample - loss: 5.4525
# Epoch 87/100
# 100/100 [==============================] - 0s 32us/sample - loss: 5.4516
# Epoch 88/100
# 100/100 [==============================] - 0s 21us/sample - loss: 5.4507
# Epoch 89/100
# 100/100 [==============================] - 0s 52us/sample - loss: 5.4499
# Epoch 90/100
# 100/100 [==============================] - 0s 23us/sample - loss: 5.4491
# Epoch 91/100
# 100/100 [==============================] - 0s 25us/sample - loss: 5.4483
# Epoch 92/100
# 100/100 [==============================] - 0s 20us/sample - loss: 5.4476
# Epoch 93/100
# 100/100 [==============================] - 0s 46us/sample - loss: 5.4468
# Epoch 94/100
# 100/100 [==============================] - 0s 28us/sample - loss: 5.4462
# Epoch 95/100
# 100/100 [==============================] - 0s 21us/sample - loss: 5.4455
# Epoch 96/100
# 100/100 [==============================] - 0s 31us/sample - loss: 5.4449
# Epoch 97/100
# 100/100 [==============================] - 0s 33us/sample - loss: 5.4443
# Epoch 98/100
# 100/100 [==============================] - 0s 31us/sample - loss: 5.4437
# Epoch 99/100
# 100/100 [==============================] - 0s 29us/sample - loss: 5.4432
# Epoch 100/100
# 100/100 [==============================] - 0s 42us/sample - loss: 5.4426

# %%
# plot the neural network's predictions

multiple_layer_linear_network_yhat = multiple_layer_linear_network.predict(x_in_batch_form)
plt.plot(x, y, label='Truth')
plt.plot(x, multiple_layer_linear_network_yhat, label='Multi-Layer, Linear Network')
plt.legend()

# %% [markdown]
# The key takeaway: a multi-layer, linear neural network trained under mean squared error is still just linear regression! The reason why is simple: two chained affine transformations is still an affine transformations
#
# \begin{align*}
# W_2(W_1 x + b_1) + b_2
# &= \underbrace{W_2 W_1}_{W_1'} x + \underbrace{W_2 b_1 + b_2}_{b_1'}\\
# &= W_1' x + b_1'
# \end{align*}
#
# Nonlinear activation functions are needed to permit neural networks to learn nonlinear functions!

# %% [markdown]
# #### Exercise 3: Suppose we fit a single layer neural network (i.e. no hidden layers) with a sigmoid activation functions. What will our model learn?

# %%
# create a single layer neural network with Sigmoid activation function

single_layer_nonlinear_network = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1, input_shape=(1,), activation='sigmoid'),
])
single_layer_nonlinear_network.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the neural network

single_layer_nonlinear_network.compile(optimizer='sgd', loss=tf.keras.losses.MeanSquaredError())
single_layer_nonlinear_network.fit(x_in_batch_form, y, epochs=100, batch_size=batch_size)
# Out:
# Train on 100 samples
# Epoch 1/100
# 100/100 [==============================] - 0s 3ms/sample - loss: 6.4540
# Epoch 2/100
# 100/100 [==============================] - 0s 27us/sample - loss: 6.4512
# Epoch 3/100
# 100/100 [==============================] - 0s 27us/sample - loss: 6.4486
# Epoch 4/100
# 100/100 [==============================] - 0s 29us/sample - loss: 6.4461
# Epoch 5/100
# 100/100 [==============================] - 0s 28us/sample - loss: 6.4437
# Epoch 6/100
# 100/100 [==============================] - 0s 27us/sample - loss: 6.4415
# Epoch 7/100
# 100/100 [==============================] - 0s 34us/sample - loss: 6.4394
# Epoch 8/100
# 100/100 [==============================] - 0s 30us/sample - loss: 6.4374
# Epoch 9/100
# 100/100 [==============================] - 0s 28us/sample - loss: 6.4355
# Epoch 10/100
# 100/100 [==============================] - 0s 19us/sample - loss: 6.4337
# Epoch 11/100
# 100/100 [==============================] - 0s 26us/sample - loss: 6.4320
# Epoch 12/100
# 100/100 [==============================] - 0s 19us/sample - loss: 6.4303
# Epoch 13/100
# 100/100 [==============================] - 0s 21us/sample - loss: 6.4288
# Epoch 14/100
# 100/100 [==============================] - 0s 26us/sample - loss: 6.4273
# Epoch 15/100
# 100/100 [==============================] - 0s 25us/sample - loss: 6.4258
# Epoch 16/100
# 100/100 [==============================] - 0s 54us/sample - loss: 6.4245
# Epoch 17/100
# 100/100 [==============================] - 0s 31us/sample - loss: 6.4232
# Epoch 18/100
# 100/100 [==============================] - 0s 22us/sample - loss: 6.4219
# Epoch 19/100
# 100/100 [==============================] - 0s 26us/sample - loss: 6.4207
# Epoch 20/100
# 100/100 [==============================] - 0s 53us/sample - loss: 6.4196
# Epoch 21/100
# 100/100 [==============================] - 0s 36us/sample - loss: 6.4185
# Epoch 22/100
# 100/100 [==============================] - 0s 22us/sample - loss: 6.4175
# Epoch 23/100
# 100/100 [==============================] - 0s 27us/sample - loss: 6.4165
# Epoch 24/100
# 100/100 [==============================] - 0s 20us/sample - loss: 6.4155
# Epoch 25/100
# 100/100 [==============================] - 0s 35us/sample - loss: 6.4146
# Epoch 26/100
# 100/100 [==============================] - 0s 24us/sample - loss: 6.4137
# Epoch 27/100
# 100/100 [==============================] - 0s 41us/sample - loss: 6.4128
# Epoch 28/100
# 100/100 [==============================] - 0s 35us/sample - loss: 6.4120
# Epoch 29/100
# 100/100 [==============================] - 0s 27us/sample - loss: 6.4112
# Epoch 30/100
# 100/100 [==============================] - 0s 20us/sample - loss: 6.4104
# Epoch 31/100
# 100/100 [==============================] - 0s 45us/sample - loss: 6.4097
# Epoch 32/100
# 100/100 [==============================] - 0s 33us/sample - loss: 6.4090
# Epoch 33/100
# 100/100 [==============================] - 0s 29us/sample - loss: 6.4083
# Epoch 34/100
# 100/100 [==============================] - 0s 36us/sample - loss: 6.4076
# Epoch 35/100
# 100/100 [==============================] - 0s 29us/sample - loss: 6.4070
# Epoch 36/100
# 100/100 [==============================] - 0s 34us/sample - loss: 6.4063
# Epoch 37/100
# 100/100 [==============================] - 0s 31us/sample - loss: 6.4058
# Epoch 38/100
# 100/100 [==============================] - 0s 28us/sample - loss: 6.4052
# Epoch 39/100
# 100/100 [==============================] - 0s 34us/sample - loss: 6.4046
# Epoch 40/100
# 100/100 [==============================] - 0s 22us/sample - loss: 6.4041
# Epoch 41/100
# 100/100 [==============================] - 0s 32us/sample - loss: 6.4035
# Epoch 42/100
# 100/100 [==============================] - 0s 27us/sample - loss: 6.4030
# Epoch 43/100
# 100/100 [==============================] - 0s 32us/sample - loss: 6.4025
# Epoch 44/100
# 100/100 [==============================] - 0s 31us/sample - loss: 6.4021
# Epoch 45/100
# 100/100 [==============================] - 0s 37us/sample - loss: 6.4016
# Epoch 46/100
# 100/100 [==============================] - 0s 25us/sample - loss: 6.4012
# Epoch 47/100
# 100/100 [==============================] - 0s 26us/sample - loss: 6.4007
# Epoch 48/100
# 100/100 [==============================] - 0s 19us/sample - loss: 6.4003
# Epoch 49/100
# 100/100 [==============================] - 0s 50us/sample - loss: 6.3999
# Epoch 50/100
# 100/100 [==============================] - 0s 35us/sample - loss: 6.3995
# Epoch 51/100
# 100/100 [==============================] - 0s 31us/sample - loss: 6.3991
# Epoch 52/100
# 100/100 [==============================] - 0s 40us/sample - loss: 6.3987
# Epoch 53/100
# 100/100 [==============================] - 0s 37us/sample - loss: 6.3984
# Epoch 54/100
# 100/100 [==============================] - 0s 29us/sample - loss: 6.3980
# Epoch 55/100
# 100/100 [==============================] - 0s 38us/sample - loss: 6.3977
# Epoch 56/100
# 100/100 [==============================] - 0s 28us/sample - loss: 6.3973
# Epoch 57/100
# 100/100 [==============================] - 0s 23us/sample - loss: 6.3970
# Epoch 58/100
# 100/100 [==============================] - 0s 35us/sample - loss: 6.3967
# Epoch 59/100
# 100/100 [==============================] - 0s 34us/sample - loss: 6.3964
# Epoch 60/100
# 100/100 [==============================] - 0s 19us/sample - loss: 6.3961
# Epoch 61/100
# 100/100 [==============================] - 0s 37us/sample - loss: 6.3958
# Epoch 62/100
# 100/100 [==============================] - 0s 64us/sample - loss: 6.3955
# Epoch 63/100
# 100/100 [==============================] - 0s 23us/sample - loss: 6.3952
# Epoch 64/100
# 100/100 [==============================] - 0s 37us/sample - loss: 6.3950
# Epoch 65/100
# 100/100 [==============================] - 0s 26us/sample - loss: 6.3947
# Epoch 66/100
# 100/100 [==============================] - 0s 18us/sample - loss: 6.3945
# Epoch 67/100
# 100/100 [==============================] - 0s 20us/sample - loss: 6.3942
# Epoch 68/100
# 100/100 [==============================] - 0s 45us/sample - loss: 6.3940
# Epoch 69/100
# 100/100 [==============================] - 0s 28us/sample - loss: 6.3937
# Epoch 70/100
# 100/100 [==============================] - 0s 20us/sample - loss: 6.3935
# Epoch 71/100
# 100/100 [==============================] - 0s 20us/sample - loss: 6.3933
# Epoch 72/100
# 100/100 [==============================] - 0s 17us/sample - loss: 6.3930
# Epoch 73/100
# 100/100 [==============================] - 0s 19us/sample - loss: 6.3928
# Epoch 74/100
# 100/100 [==============================] - 0s 32us/sample - loss: 6.3926
# Epoch 75/100
# 100/100 [==============================] - 0s 23us/sample - loss: 6.3924
# Epoch 76/100
# 100/100 [==============================] - 0s 22us/sample - loss: 6.3922
# Epoch 77/100
# 100/100 [==============================] - 0s 34us/sample - loss: 6.3920
# Epoch 78/100
# 100/100 [==============================] - 0s 18us/sample - loss: 6.3918
# Epoch 79/100
# 100/100 [==============================] - 0s 17us/sample - loss: 6.3916
# Epoch 80/100
# 100/100 [==============================] - 0s 17us/sample - loss: 6.3914
# Epoch 81/100
# 100/100 [==============================] - 0s 14us/sample - loss: 6.3913
# Epoch 82/100
# 100/100 [==============================] - 0s 14us/sample - loss: 6.3911
# Epoch 83/100
# 100/100 [==============================] - 0s 15us/sample - loss: 6.3909
# Epoch 84/100
# 100/100 [==============================] - 0s 27us/sample - loss: 6.3907
# Epoch 85/100
# 100/100 [==============================] - 0s 16us/sample - loss: 6.3906
# Epoch 86/100
# 100/100 [==============================] - 0s 15us/sample - loss: 6.3904
# Epoch 87/100
# 100/100 [==============================] - 0s 17us/sample - loss: 6.3903
# Epoch 88/100
# 100/100 [==============================] - 0s 19us/sample - loss: 6.3901
# Epoch 89/100
# 100/100 [==============================] - 0s 16us/sample - loss: 6.3899
# Epoch 90/100
# 100/100 [==============================] - 0s 15us/sample - loss: 6.3898
# Epoch 91/100
# 100/100 [==============================] - 0s 13us/sample - loss: 6.3896
# Epoch 92/100
# 100/100 [==============================] - 0s 20us/sample - loss: 6.3895
# Epoch 93/100
# 100/100 [==============================] - 0s 13us/sample - loss: 6.3894
# Epoch 94/100
# 100/100 [==============================] - 0s 12us/sample - loss: 6.3892
# Epoch 95/100
# 100/100 [==============================] - 0s 14us/sample - loss: 6.3891
# Epoch 96/100
# 100/100 [==============================] - 0s 13us/sample - loss: 6.3890
# Epoch 97/100
# 100/100 [==============================] - 0s 17us/sample - loss: 6.3888
# Epoch 98/100
# 100/100 [==============================] - 0s 28us/sample - loss: 6.3887
# Epoch 99/100
# 100/100 [==============================] - 0s 21us/sample - loss: 6.3886
# Epoch 100/100
# 100/100 [==============================] - 0s 15us/sample - loss: 6.3885

# %%
# plot the neural network's predictions

single_layer_nonlinear_network_yhat = single_layer_nonlinear_network.predict(x_in_batch_form)
plt.plot(x, y, label='Truth')
plt.plot(x, single_layer_nonlinear_network_yhat, label='Single Layer, Sigmoid Network')
plt.legend()

# %% [markdown]
# Although not immediately obvious, this is actually logistic regression! Let's plot the predictions from the network over a wider range of x values:

# %%
x_wider = np.linspace(-10, 10, 1000).reshape(1000, 1)
single_layer_nonlinear_network_yhat_wider = single_layer_nonlinear_network.predict(x_wider)
# plt.plot(x, y, label='Truth')
plt.plot(x_wider, single_layer_nonlinear_network_yhat_wider, color='tab:orange', label='Single Layer, Sigmoid Network')

# %% [markdown]
# Key takeaway: a single layer neural network with a sigmoid activation function is logistic regression! Mathematically, this makes sense:
#
# $$NN(x) = \sigma(Wx + b) = \frac{1}{1 + e^{-(Wx + b)}} $$

# %% [markdown]
# #### Exercise 4: Suppose we permit a hidden layer with sigmoid activation functions. What will our model learn as a function of the hidden layer dimension?

# %%
# create many neural network with Sigmoid activation function

dims_to_consider = [1, 10, 50, 100]
single_hidden_results = {}

for dim_to_consider in dims_to_consider:
    hidden_layer_nonlinear_network = tf.keras.models.Sequential([
        tf.keras.layers.Dense(dim_to_consider, input_shape=(1,), activation='sigmoid'),
        tf.keras.layers.Dense(1,),
    ])
    hidden_layer_nonlinear_network.compile(optimizer='sgd', loss=tf.keras.losses.MeanSquaredError())
    hidden_layer_nonlinear_network.fit(x_in_batch_form, y, epochs=200, batch_size=batch_size)
    single_hidden_results[dim_to_consider] = hidden_layer_nonlinear_network.predict(x_in_batch_form)
# Out:
# Train on 100 samples
# Epoch 1/200
# 100/100 [==============================] - 0s 3ms/sample - loss: 6.0104
# Epoch 2/200
# 100/100 [==============================] - 0s 39us/sample - loss: 6.0072
# Epoch 3/200
# 100/100 [==============================] - 0s 32us/sample - loss: 6.0042
# Epoch 4/200
# 100/100 [==============================] - 0s 28us/sample - loss: 6.0014
# Epoch 5/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.9989
# Epoch 6/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.9965
# Epoch 7/200
# 100/100 [==============================] - 0s 25us/sample - loss: 5.9943
# Epoch 8/200
# 100/100 [==============================] - 0s 39us/sample - loss: 5.9922
# Epoch 9/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.9903
# Epoch 10/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9885
# Epoch 11/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.9868
# Epoch 12/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.9852
# Epoch 13/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.9837
# Epoch 14/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9824
# Epoch 15/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.9811
# Epoch 16/200
# 100/100 [==============================] - 0s 58us/sample - loss: 5.9799
# Epoch 17/200
# 100/100 [==============================] - 0s 35us/sample - loss: 5.9788
# Epoch 18/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.9777
# Epoch 19/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.9767
# Epoch 20/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.9758
# Epoch 21/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.9749
# Epoch 22/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.9741
# Epoch 23/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.9733
# Epoch 24/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.9725
# Epoch 25/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.9718
# Epoch 26/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.9712
# Epoch 27/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.9706
# Epoch 28/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.9700
# Epoch 29/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.9694
# Epoch 30/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.9689
# Epoch 31/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.9684
# Epoch 32/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.9679
# Epoch 33/200
# 100/100 [==============================] - 0s 25us/sample - loss: 5.9674
# Epoch 34/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.9670
# Epoch 35/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.9665
# Epoch 36/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.9661
# Epoch 37/200
# 100/100 [==============================] - 0s 55us/sample - loss: 5.9657
# Epoch 38/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.9653
# Epoch 39/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.9650
# Epoch 40/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.9646
# Epoch 41/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.9643
# Epoch 42/200
# 100/100 [==============================] - 0s 37us/sample - loss: 5.9639
# Epoch 43/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.9636
# Epoch 44/200
# 100/100 [==============================] - 0s 35us/sample - loss: 5.9633
# Epoch 45/200
# 100/100 [==============================] - 0s 71us/sample - loss: 5.9630
# Epoch 46/200
# 100/100 [==============================] - 0s 34us/sample - loss: 5.9627
# Epoch 47/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.9624
# Epoch 48/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.9621
# Epoch 49/200
# 100/100 [==============================] - 0s 34us/sample - loss: 5.9618
# Epoch 50/200
# 100/100 [==============================] - 0s 30us/sample - loss: 5.9615
# Epoch 51/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.9612
# Epoch 52/200
# 100/100 [==============================] - 0s 70us/sample - loss: 5.9610
# Epoch 53/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.9607
# Epoch 54/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.9604
# Epoch 55/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.9602
# Epoch 56/200
# 100/100 [==============================] - 0s 40us/sample - loss: 5.9599
# Epoch 57/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.9597
# Epoch 58/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.9594
# Epoch 59/200
# 100/100 [==============================] - 0s 54us/sample - loss: 5.9592
# Epoch 60/200
# 100/100 [==============================] - 0s 40us/sample - loss: 5.9589
# Epoch 61/200
# 100/100 [==============================] - 0s 59us/sample - loss: 5.9587
# Epoch 62/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.9584
# Epoch 63/200
# 100/100 [==============================] - 0s 31us/sample - loss: 5.9582
# Epoch 64/200
# 100/100 [==============================] - 0s 50us/sample - loss: 5.9580
# Epoch 65/200
# 100/100 [==============================] - 0s 32us/sample - loss: 5.9577
# Epoch 66/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.9575
# Epoch 67/200
# 100/100 [==============================] - 0s 58us/sample - loss: 5.9572
# Epoch 68/200
# 100/100 [==============================] - 0s 31us/sample - loss: 5.9570
# Epoch 69/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.9568
# Epoch 70/200
# 100/100 [==============================] - 0s 52us/sample - loss: 5.9565
# Epoch 71/200
# 100/100 [==============================] - 0s 36us/sample - loss: 5.9563
# Epoch 72/200
# 100/100 [==============================] - 0s 48us/sample - loss: 5.9561
# Epoch 73/200
# 100/100 [==============================] - 0s 25us/sample - loss: 5.9558
# Epoch 74/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.9556
# Epoch 75/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.9553
# Epoch 76/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9551
# Epoch 77/200
# 100/100 [==============================] - 0s 62us/sample - loss: 5.9549
# Epoch 78/200
# 100/100 [==============================] - 0s 35us/sample - loss: 5.9546
# Epoch 79/200
# 100/100 [==============================] - 0s 36us/sample - loss: 5.9544
# Epoch 80/200
# 100/100 [==============================] - 0s 35us/sample - loss: 5.9542
# Epoch 81/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.9539
# Epoch 82/200
# 100/100 [==============================] - 0s 57us/sample - loss: 5.9537
# Epoch 83/200
# 100/100 [==============================] - 0s 36us/sample - loss: 5.9535
# Epoch 84/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.9532
# Epoch 85/200
# 100/100 [==============================] - 0s 45us/sample - loss: 5.9530
# Epoch 86/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.9527
# Epoch 87/200
# 100/100 [==============================] - 0s 36us/sample - loss: 5.9525
# Epoch 88/200
# 100/100 [==============================] - 0s 50us/sample - loss: 5.9523
# Epoch 89/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.9520
# Epoch 90/200
# 100/100 [==============================] - 0s 43us/sample - loss: 5.9518
# Epoch 91/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.9515
# Epoch 92/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.9513
# Epoch 93/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.9510
# Epoch 94/200
# 100/100 [==============================] - 0s 41us/sample - loss: 5.9508
# Epoch 95/200
# 100/100 [==============================] - 0s 25us/sample - loss: 5.9506
# Epoch 96/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9503
# Epoch 97/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.9501
# Epoch 98/200
# 100/100 [==============================] - 0s 36us/sample - loss: 5.9498
# Epoch 99/200
# 100/100 [==============================] - 0s 42us/sample - loss: 5.9496
# Epoch 100/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.9493
# Epoch 101/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.9491
# Epoch 102/200
# 100/100 [==============================] - 0s 34us/sample - loss: 5.9488
# Epoch 103/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.9486
# Epoch 104/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.9483
# Epoch 105/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.9481
# Epoch 106/200
# 100/100 [==============================] - 0s 38us/sample - loss: 5.9478
# Epoch 107/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.9476
# Epoch 108/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.9473
# Epoch 109/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.9470
# Epoch 110/200
# 100/100 [==============================] - 0s 38us/sample - loss: 5.9468
# Epoch 111/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.9465
# Epoch 112/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.9463
# Epoch 113/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.9460
# Epoch 114/200
# 100/100 [==============================] - 0s 30us/sample - loss: 5.9457
# Epoch 115/200
# 100/100 [==============================] - 0s 30us/sample - loss: 5.9455
# Epoch 116/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.9452
# Epoch 117/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.9449
# Epoch 118/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.9447
# Epoch 119/200
# 100/100 [==============================] - 0s 37us/sample - loss: 5.9444
# Epoch 120/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.9441
# Epoch 121/200
# 100/100 [==============================] - 0s 25us/sample - loss: 5.9439
# Epoch 122/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.9436
# Epoch 123/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.9433
# Epoch 124/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9430
# Epoch 125/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9428
# Epoch 126/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.9425
# Epoch 127/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9422
# Epoch 128/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.9419
# Epoch 129/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.9417
# Epoch 130/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.9414
# Epoch 131/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.9411
# Epoch 132/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.9408
# Epoch 133/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.9405
# Epoch 134/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.9402
# Epoch 135/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.9400
# Epoch 136/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.9397
# Epoch 137/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.9394
# Epoch 138/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.9391
# Epoch 139/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.9388
# Epoch 140/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.9385
# Epoch 141/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.9382
# Epoch 142/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.9379
# Epoch 143/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.9376
# Epoch 144/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.9373
# Epoch 145/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.9370
# Epoch 146/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.9367
# Epoch 147/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.9364
# Epoch 148/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.9361
# Epoch 149/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.9358
# Epoch 150/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.9355
# Epoch 151/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.9352
# Epoch 152/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.9349
# Epoch 153/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.9346
# Epoch 154/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.9343
# Epoch 155/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.9340
# Epoch 156/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.9336
# Epoch 157/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9333
# Epoch 158/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9330
# Epoch 159/200
# 100/100 [==============================] - 0s 34us/sample - loss: 5.9327
# Epoch 160/200
# 100/100 [==============================] - 0s 31us/sample - loss: 5.9324
# Epoch 161/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.9321
# Epoch 162/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9317
# Epoch 163/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.9314
# Epoch 164/200
# 100/100 [==============================] - 0s 36us/sample - loss: 5.9311
# Epoch 165/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9308
# Epoch 166/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.9304
# Epoch 167/200
# 100/100 [==============================] - 0s 31us/sample - loss: 5.9301
# Epoch 168/200
# 100/100 [==============================] - 0s 47us/sample - loss: 5.9298
# Epoch 169/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.9294
# Epoch 170/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.9291
# Epoch 171/200
# 100/100 [==============================] - 0s 38us/sample - loss: 5.9288
# Epoch 172/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.9284
# Epoch 173/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9281
# Epoch 174/200
# 100/100 [==============================] - 0s 39us/sample - loss: 5.9277
# Epoch 175/200
# 100/100 [==============================] - 0s 32us/sample - loss: 5.9274
# Epoch 176/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.9270
# Epoch 177/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.9267
# Epoch 178/200
# 100/100 [==============================] - 0s 36us/sample - loss: 5.9264
# Epoch 179/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.9260
# Epoch 180/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.9257
# Epoch 181/200
# 100/100 [==============================] - 0s 50us/sample - loss: 5.9253
# Epoch 182/200
# 100/100 [==============================] - 0s 46us/sample - loss: 5.9249
# Epoch 183/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.9246
# Epoch 184/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.9242
# Epoch 185/200
# 100/100 [==============================] - 0s 31us/sample - loss: 5.9239
# Epoch 186/200
# 100/100 [==============================] - 0s 37us/sample - loss: 5.9235
# Epoch 187/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.9231
# Epoch 188/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9228
# Epoch 189/200
# 100/100 [==============================] - 0s 36us/sample - loss: 5.9224
# Epoch 190/200
# 100/100 [==============================] - 0s 30us/sample - loss: 5.9220
# Epoch 191/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.9217
# Epoch 192/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.9213
# Epoch 193/200
# 100/100 [==============================] - 0s 37us/sample - loss: 5.9209
# Epoch 194/200
# 100/100 [==============================] - 0s 51us/sample - loss: 5.9205
# Epoch 195/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.9202
# Epoch 196/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.9198
# Epoch 197/200
# 100/100 [==============================] - 0s 34us/sample - loss: 5.9194
# Epoch 198/200
# 100/100 [==============================] - 0s 34us/sample - loss: 5.9190
# Epoch 199/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9186
# Epoch 200/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.9183
# Train on 100 samples
# Epoch 1/200
# 100/100 [==============================] - 0s 2ms/sample - loss: 6.8219
# Epoch 2/200
# 100/100 [==============================] - 0s 14us/sample - loss: 6.6863
# Epoch 3/200
# 100/100 [==============================] - 0s 16us/sample - loss: 6.5727
# Epoch 4/200
# 100/100 [==============================] - 0s 14us/sample - loss: 6.4773
# Epoch 5/200
# 100/100 [==============================] - 0s 13us/sample - loss: 6.3967
# Epoch 6/200
# 100/100 [==============================] - 0s 11us/sample - loss: 6.3284
# Epoch 7/200
# 100/100 [==============================] - 0s 11us/sample - loss: 6.2702
# Epoch 8/200
# 100/100 [==============================] - 0s 12us/sample - loss: 6.2204
# Epoch 9/200
# 100/100 [==============================] - 0s 20us/sample - loss: 6.1775
# Epoch 10/200
# 100/100 [==============================] - 0s 20us/sample - loss: 6.1404
# Epoch 11/200
# 100/100 [==============================] - 0s 11us/sample - loss: 6.1081
# Epoch 12/200
# 100/100 [==============================] - 0s 12us/sample - loss: 6.0799
# Epoch 13/200
# 100/100 [==============================] - 0s 11us/sample - loss: 6.0549
# Epoch 14/200
# 100/100 [==============================] - 0s 12us/sample - loss: 6.0328
# Epoch 15/200
# 100/100 [==============================] - 0s 13us/sample - loss: 6.0130
# Epoch 16/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.9952
# Epoch 17/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.9791
# Epoch 18/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.9643
# Epoch 19/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.9508
# Epoch 20/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.9383
# Epoch 21/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.9266
# Epoch 22/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.9156
# Epoch 23/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.9053
# Epoch 24/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.8955
# Epoch 25/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.8861
# Epoch 26/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.8772
# Epoch 27/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.8686
# Epoch 28/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.8603
# Epoch 29/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.8522
# Epoch 30/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.8444
# Epoch 31/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.8368
# Epoch 32/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.8294
# Epoch 33/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.8221
# Epoch 34/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.8150
# Epoch 35/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.8080
# Epoch 36/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.8012
# Epoch 37/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.7944
# Epoch 38/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.7878
# Epoch 39/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.7813
# Epoch 40/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.7748
# Epoch 41/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.7685
# Epoch 42/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.7622
# Epoch 43/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.7560
# Epoch 44/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.7498
# Epoch 45/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.7438
# Epoch 46/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.7378
# Epoch 47/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.7318
# Epoch 48/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.7260
# Epoch 49/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.7202
# Epoch 50/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.7144
# Epoch 51/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.7087
# Epoch 52/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.7031
# Epoch 53/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.6975
# Epoch 54/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.6920
# Epoch 55/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.6865
# Epoch 56/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.6811
# Epoch 57/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.6758
# Epoch 58/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.6705
# Epoch 59/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.6652
# Epoch 60/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.6600
# Epoch 61/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.6548
# Epoch 62/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.6497
# Epoch 63/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.6447
# Epoch 64/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.6396
# Epoch 65/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.6347
# Epoch 66/200
# 100/100 [==============================] - 0s 25us/sample - loss: 5.6297
# Epoch 67/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.6249
# Epoch 68/200
# 100/100 [==============================] - 0s 36us/sample - loss: 5.6200
# Epoch 69/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.6152
# Epoch 70/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.6105
# Epoch 71/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.6058
# Epoch 72/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.6011
# Epoch 73/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.5965
# Epoch 74/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.5919
# Epoch 75/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.5874
# Epoch 76/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.5829
# Epoch 77/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.5784
# Epoch 78/200
# 100/100 [==============================] - 0s 32us/sample - loss: 5.5740
# Epoch 79/200
# 100/100 [==============================] - 0s 30us/sample - loss: 5.5696
# Epoch 80/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.5653
# Epoch 81/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.5610
# Epoch 82/200
# 100/100 [==============================] - 0s 39us/sample - loss: 5.5567
# Epoch 83/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.5525
# Epoch 84/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.5483
# Epoch 85/200
# 100/100 [==============================] - 0s 40us/sample - loss: 5.5441
# Epoch 86/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.5400
# Epoch 87/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.5359
# Epoch 88/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.5319
# Epoch 89/200
# 100/100 [==============================] - 0s 49us/sample - loss: 5.5279
# Epoch 90/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.5239
# Epoch 91/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.5200
# Epoch 92/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.5161
# Epoch 93/200
# 100/100 [==============================] - 0s 37us/sample - loss: 5.5122
# Epoch 94/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.5084
# Epoch 95/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.5045
# Epoch 96/200
# 100/100 [==============================] - 0s 42us/sample - loss: 5.5008
# Epoch 97/200
# 100/100 [==============================] - 0s 31us/sample - loss: 5.4970
# Epoch 98/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.4933
# Epoch 99/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.4896
# Epoch 100/200
# 100/100 [==============================] - 0s 36us/sample - loss: 5.4860
# Epoch 101/200
# 100/100 [==============================] - 0s 34us/sample - loss: 5.4824
# Epoch 102/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.4788
# Epoch 103/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.4752
# Epoch 104/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.4717
# Epoch 105/200
# 100/100 [==============================] - 0s 31us/sample - loss: 5.4682
# Epoch 106/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.4647
# Epoch 107/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.4613
# Epoch 108/200
# 100/100 [==============================] - 0s 54us/sample - loss: 5.4579
# Epoch 109/200
# 100/100 [==============================] - 0s 44us/sample - loss: 5.4545
# Epoch 110/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.4512
# Epoch 111/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.4478
# Epoch 112/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.4445
# Epoch 113/200
# 100/100 [==============================] - 0s 25us/sample - loss: 5.4413
# Epoch 114/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.4380
# Epoch 115/200
# 100/100 [==============================] - 0s 36us/sample - loss: 5.4348
# Epoch 116/200
# 100/100 [==============================] - 0s 41us/sample - loss: 5.4316
# Epoch 117/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.4284
# Epoch 118/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.4253
# Epoch 119/200
# 100/100 [==============================] - 0s 75us/sample - loss: 5.4222
# Epoch 120/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.4191
# Epoch 121/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.4160
# Epoch 122/200
# 100/100 [==============================] - 0s 34us/sample - loss: 5.4130
# Epoch 123/200
# 100/100 [==============================] - 0s 25us/sample - loss: 5.4100
# Epoch 124/200
# 100/100 [==============================] - 0s 30us/sample - loss: 5.4070
# Epoch 125/200
# 100/100 [==============================] - 0s 53us/sample - loss: 5.4040
# Epoch 126/200
# 100/100 [==============================] - 0s 31us/sample - loss: 5.4011
# Epoch 127/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.3982
# Epoch 128/200
# 100/100 [==============================] - 0s 32us/sample - loss: 5.3953
# Epoch 129/200
# 100/100 [==============================] - 0s 41us/sample - loss: 5.3924
# Epoch 130/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.3896
# Epoch 131/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.3868
# Epoch 132/200
# 100/100 [==============================] - 0s 42us/sample - loss: 5.3840
# Epoch 133/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.3812
# Epoch 134/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.3784
# Epoch 135/200
# 100/100 [==============================] - 0s 35us/sample - loss: 5.3757
# Epoch 136/200
# 100/100 [==============================] - 0s 46us/sample - loss: 5.3730
# Epoch 137/200
# 100/100 [==============================] - 0s 34us/sample - loss: 5.3703
# Epoch 138/200
# 100/100 [==============================] - 0s 41us/sample - loss: 5.3676
# Epoch 139/200
# 100/100 [==============================] - 0s 45us/sample - loss: 5.3650
# Epoch 140/200
# 100/100 [==============================] - 0s 34us/sample - loss: 5.3623
# Epoch 141/200
# 100/100 [==============================] - 0s 52us/sample - loss: 5.3597
# Epoch 142/200
# 100/100 [==============================] - 0s 35us/sample - loss: 5.3571
# Epoch 143/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.3546
# Epoch 144/200
# 100/100 [==============================] - 0s 35us/sample - loss: 5.3520
# Epoch 145/200
# 100/100 [==============================] - 0s 34us/sample - loss: 5.3495
# Epoch 146/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.3470
# Epoch 147/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.3445
# Epoch 148/200
# 100/100 [==============================] - 0s 40us/sample - loss: 5.3420
# Epoch 149/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.3396
# Epoch 150/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.3372
# Epoch 151/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.3348
# Epoch 152/200
# 100/100 [==============================] - 0s 50us/sample - loss: 5.3324
# Epoch 153/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.3300
# Epoch 154/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.3276
# Epoch 155/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.3253
# Epoch 156/200
# 100/100 [==============================] - 0s 41us/sample - loss: 5.3230
# Epoch 157/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.3207
# Epoch 158/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.3184
# Epoch 159/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.3161
# Epoch 160/200
# 100/100 [==============================] - 0s 48us/sample - loss: 5.3139
# Epoch 161/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.3117
# Epoch 162/200
# 100/100 [==============================] - 0s 30us/sample - loss: 5.3094
# Epoch 163/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.3072
# Epoch 164/200
# 100/100 [==============================] - 0s 30us/sample - loss: 5.3051
# Epoch 165/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.3029
# Epoch 166/200
# 100/100 [==============================] - 0s 31us/sample - loss: 5.3008
# Epoch 167/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.2986
# Epoch 168/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.2965
# Epoch 169/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.2944
# Epoch 170/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.2923
# Epoch 171/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.2903
# Epoch 172/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.2882
# Epoch 173/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.2862
# Epoch 174/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.2842
# Epoch 175/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.2822
# Epoch 176/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.2802
# Epoch 177/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.2782
# Epoch 178/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.2763
# Epoch 179/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.2743
# Epoch 180/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.2724
# Epoch 181/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.2705
# Epoch 182/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.2686
# Epoch 183/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.2667
# Epoch 184/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.2648
# Epoch 185/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.2630
# Epoch 186/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.2611
# Epoch 187/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.2593
# Epoch 188/200
# 100/100 [==============================] - 0s 25us/sample - loss: 5.2575
# Epoch 189/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.2557
# Epoch 190/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.2539
# Epoch 191/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2521
# Epoch 192/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.2504
# Epoch 193/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.2486
# Epoch 194/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.2469
# Epoch 195/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.2452
# Epoch 196/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.2434
# Epoch 197/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.2417
# Epoch 198/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2401
# Epoch 199/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.2384
# Epoch 200/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2367
# Train on 100 samples
# Epoch 1/200
# 100/100 [==============================] - 0s 2ms/sample - loss: 11.1038
# Epoch 2/200
# 100/100 [==============================] - 0s 12us/sample - loss: 8.2295
# Epoch 3/200
# 100/100 [==============================] - 0s 11us/sample - loss: 6.9780
# Epoch 4/200
# 100/100 [==============================] - 0s 11us/sample - loss: 6.4221
# Epoch 5/200
# 100/100 [==============================] - 0s 14us/sample - loss: 6.1692
# Epoch 6/200
# 100/100 [==============================] - 0s 15us/sample - loss: 6.0492
# Epoch 7/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.9878
# Epoch 8/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.9522
# Epoch 9/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.9282
# Epoch 10/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.9095
# Epoch 11/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.8932
# Epoch 12/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.8782
# Epoch 13/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.8639
# Epoch 14/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.8501
# Epoch 15/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.8367
# Epoch 16/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.8236
# Epoch 17/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.8108
# Epoch 18/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.7982
# Epoch 19/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.7860
# Epoch 20/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.7739
# Epoch 21/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.7622
# Epoch 22/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.7506
# Epoch 23/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.7393
# Epoch 24/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.7283
# Epoch 25/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.7174
# Epoch 26/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.7068
# Epoch 27/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.6964
# Epoch 28/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.6862
# Epoch 29/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.6762
# Epoch 30/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.6664
# Epoch 31/200
# 100/100 [==============================] - 0s 9us/sample - loss: 5.6568
# Epoch 32/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.6475
# Epoch 33/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.6382
# Epoch 34/200
# 100/100 [==============================] - 0s 25us/sample - loss: 5.6292
# Epoch 35/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.6204
# Epoch 36/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.6117
# Epoch 37/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.6032
# Epoch 38/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.5948
# Epoch 39/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.5867
# Epoch 40/200
# 100/100 [==============================] - 0s 35us/sample - loss: 5.5786
# Epoch 41/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.5708
# Epoch 42/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.5631
# Epoch 43/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.5555
# Epoch 44/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.5481
# Epoch 45/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.5408
# Epoch 46/200
# 100/100 [==============================] - 0s 25us/sample - loss: 5.5337
# Epoch 47/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.5267
# Epoch 48/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.5198
# Epoch 49/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.5131
# Epoch 50/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.5065
# Epoch 51/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.5000
# Epoch 52/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.4937
# Epoch 53/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.4874
# Epoch 54/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.4813
# Epoch 55/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.4753
# Epoch 56/200
# 100/100 [==============================] - 0s 37us/sample - loss: 5.4694
# Epoch 57/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.4637
# Epoch 58/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.4580
# Epoch 59/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.4524
# Epoch 60/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.4470
# Epoch 61/200
# 100/100 [==============================] - 0s 39us/sample - loss: 5.4416
# Epoch 62/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.4363
# Epoch 63/200
# 100/100 [==============================] - 0s 39us/sample - loss: 5.4312
# Epoch 64/200
# 100/100 [==============================] - 0s 53us/sample - loss: 5.4261
# Epoch 65/200
# 100/100 [==============================] - 0s 39us/sample - loss: 5.4211
# Epoch 66/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.4162
# Epoch 67/200
# 100/100 [==============================] - 0s 41us/sample - loss: 5.4115
# Epoch 68/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.4067
# Epoch 69/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.4021
# Epoch 70/200
# 100/100 [==============================] - 0s 57us/sample - loss: 5.3976
# Epoch 71/200
# 100/100 [==============================] - 0s 30us/sample - loss: 5.3931
# Epoch 72/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.3888
# Epoch 73/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.3845
# Epoch 74/200
# 100/100 [==============================] - 0s 36us/sample - loss: 5.3803
# Epoch 75/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.3761
# Epoch 76/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.3720
# Epoch 77/200
# 100/100 [==============================] - 0s 31us/sample - loss: 5.3681
# Epoch 78/200
# 100/100 [==============================] - 0s 40us/sample - loss: 5.3641
# Epoch 79/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.3603
# Epoch 80/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.3565
# Epoch 81/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.3528
# Epoch 82/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.3491
# Epoch 83/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.3456
# Epoch 84/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.3420
# Epoch 85/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.3386
# Epoch 86/200
# 100/100 [==============================] - 0s 41us/sample - loss: 5.3352
# Epoch 87/200
# 100/100 [==============================] - 0s 28us/sample - loss: 5.3318
# Epoch 88/200
# 100/100 [==============================] - 0s 34us/sample - loss: 5.3286
# Epoch 89/200
# 100/100 [==============================] - 0s 42us/sample - loss: 5.3253
# Epoch 90/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.3222
# Epoch 91/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.3191
# Epoch 92/200
# 100/100 [==============================] - 0s 43us/sample - loss: 5.3160
# Epoch 93/200
# 100/100 [==============================] - 0s 30us/sample - loss: 5.3130
# Epoch 94/200
# 100/100 [==============================] - 0s 41us/sample - loss: 5.3101
# Epoch 95/200
# 100/100 [==============================] - 0s 32us/sample - loss: 5.3072
# Epoch 96/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.3043
# Epoch 97/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.3015
# Epoch 98/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.2988
# Epoch 99/200
# 100/100 [==============================] - 0s 30us/sample - loss: 5.2961
# Epoch 100/200
# 100/100 [==============================] - 0s 40us/sample - loss: 5.2934
# Epoch 101/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.2908
# Epoch 102/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.2882
# Epoch 103/200
# 100/100 [==============================] - 0s 45us/sample - loss: 5.2857
# Epoch 104/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.2832
# Epoch 105/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.2808
# Epoch 106/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.2784
# Epoch 107/200
# 100/100 [==============================] - 0s 42us/sample - loss: 5.2760
# Epoch 108/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.2737
# Epoch 109/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.2714
# Epoch 110/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.2692
# Epoch 111/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.2670
# Epoch 112/200
# 100/100 [==============================] - 0s 36us/sample - loss: 5.2648
# Epoch 113/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.2627
# Epoch 114/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.2606
# Epoch 115/200
# 100/100 [==============================] - 0s 30us/sample - loss: 5.2585
# Epoch 116/200
# 100/100 [==============================] - 0s 37us/sample - loss: 5.2565
# Epoch 117/200
# 100/100 [==============================] - 0s 25us/sample - loss: 5.2545
# Epoch 118/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.2525
# Epoch 119/200
# 100/100 [==============================] - 0s 27us/sample - loss: 5.2506
# Epoch 120/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.2487
# Epoch 121/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.2468
# Epoch 122/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.2450
# Epoch 123/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.2432
# Epoch 124/200
# 100/100 [==============================] - 0s 33us/sample - loss: 5.2414
# Epoch 125/200
# 100/100 [==============================] - 0s 29us/sample - loss: 5.2396
# Epoch 126/200
# 100/100 [==============================] - 0s 26us/sample - loss: 5.2379
# Epoch 127/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.2362
# Epoch 128/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.2345
# Epoch 129/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.2329
# Epoch 130/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.2313
# Epoch 131/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.2297
# Epoch 132/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.2281
# Epoch 133/200
# 100/100 [==============================] - 0s 24us/sample - loss: 5.2266
# Epoch 134/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.2251
# Epoch 135/200
# 100/100 [==============================] - 0s 25us/sample - loss: 5.2236
# Epoch 136/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.2221
# Epoch 137/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.2206
# Epoch 138/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.2192
# Epoch 139/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.2178
# Epoch 140/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.2164
# Epoch 141/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.2150
# Epoch 142/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.2137
# Epoch 143/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.2124
# Epoch 144/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.2111
# Epoch 145/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.2098
# Epoch 146/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2085
# Epoch 147/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2072
# Epoch 148/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2060
# Epoch 149/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.2048
# Epoch 150/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.2036
# Epoch 151/200
# 100/100 [==============================] - 0s 31us/sample - loss: 5.2024
# Epoch 152/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.2013
# Epoch 153/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.2001
# Epoch 154/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.1990
# Epoch 155/200
# ...
# 100/100 [==============================] - 0s 11us/sample - loss: 5.6480
# Epoch 17/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.6381
# Epoch 18/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.6284
# Epoch 19/200
# 100/100 [==============================] - 0s 9us/sample - loss: 5.6190
# Epoch 20/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.6098
# Epoch 21/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.6008
# Epoch 22/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.5920
# Epoch 23/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.5835
# Epoch 24/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.5752
# Epoch 25/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.5671
# Epoch 26/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.5592
# Epoch 27/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.5515
# Epoch 28/200
# 100/100 [==============================] - 0s 9us/sample - loss: 5.5440
# Epoch 29/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.5366
# Epoch 30/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.5295
# Epoch 31/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.5225
# Epoch 32/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.5157
# Epoch 33/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.5091
# Epoch 34/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.5027
# Epoch 35/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.4964
# Epoch 36/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.4902
# Epoch 37/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.4843
# Epoch 38/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.4784
# Epoch 39/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.4727
# Epoch 40/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.4672
# Epoch 41/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.4618
# Epoch 42/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.4565
# Epoch 43/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.4513
# Epoch 44/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.4463
# Epoch 45/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.4414
# Epoch 46/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.4366
# Epoch 47/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.4320
# Epoch 48/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.4274
# Epoch 49/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.4230
# Epoch 50/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.4187
# Epoch 51/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.4145
# Epoch 52/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.4103
# Epoch 53/200
# 100/100 [==============================] - 0s 19us/sample - loss: 5.4063
# Epoch 54/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.4024
# Epoch 55/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.3986
# Epoch 56/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.3949
# Epoch 57/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.3912
# Epoch 58/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.3877
# Epoch 59/200
# 100/100 [==============================] - 0s 23us/sample - loss: 5.3842
# Epoch 60/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.3808
# Epoch 61/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.3775
# Epoch 62/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.3743
# Epoch 63/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.3712
# Epoch 64/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.3681
# Epoch 65/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.3651
# Epoch 66/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.3622
# Epoch 67/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.3593
# Epoch 68/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.3566
# Epoch 69/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.3538
# Epoch 70/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.3512
# Epoch 71/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.3486
# Epoch 72/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.3461
# Epoch 73/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.3436
# Epoch 74/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.3412
# Epoch 75/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.3388
# Epoch 76/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.3365
# Epoch 77/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.3343
# Epoch 78/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.3321
# Epoch 79/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.3299
# Epoch 80/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.3278
# Epoch 81/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.3258
# Epoch 82/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.3238
# Epoch 83/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.3218
# Epoch 84/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.3199
# Epoch 85/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.3180
# Epoch 86/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.3162
# Epoch 87/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.3144
# Epoch 88/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.3126
# Epoch 89/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.3109
# Epoch 90/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.3092
# Epoch 91/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.3076
# Epoch 92/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.3060
# Epoch 93/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.3044
# Epoch 94/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.3029
# Epoch 95/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.3014
# Epoch 96/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.2999
# Epoch 97/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2985
# Epoch 98/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.2971
# Epoch 99/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.2957
# Epoch 100/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.2943
# Epoch 101/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.2930
# Epoch 102/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.2917
# Epoch 103/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.2904
# Epoch 104/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.2891
# Epoch 105/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.2879
# Epoch 106/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.2867
# Epoch 107/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.2855
# Epoch 108/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.2844
# Epoch 109/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2832
# Epoch 110/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2821
# Epoch 111/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2810
# Epoch 112/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2799
# Epoch 113/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.2789
# Epoch 114/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2779
# Epoch 115/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.2768
# Epoch 116/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.2758
# Epoch 117/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2748
# Epoch 118/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2739
# Epoch 119/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.2729
# Epoch 120/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2720
# Epoch 121/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2711
# Epoch 122/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.2702
# Epoch 123/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.2693
# Epoch 124/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2684
# Epoch 125/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2675
# Epoch 126/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.2667
# Epoch 127/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.2658
# Epoch 128/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2650
# Epoch 129/200
# 100/100 [==============================] - 0s 9us/sample - loss: 5.2642
# Epoch 130/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2634
# Epoch 131/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2626
# Epoch 132/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2618
# Epoch 133/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.2611
# Epoch 134/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2603
# Epoch 135/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2596
# Epoch 136/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2588
# Epoch 137/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2581
# Epoch 138/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2574
# Epoch 139/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.2567
# Epoch 140/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.2560
# Epoch 141/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2553
# Epoch 142/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2546
# Epoch 143/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2539
# Epoch 144/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2532
# Epoch 145/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2526
# Epoch 146/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2519
# Epoch 147/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2513
# Epoch 148/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2506
# Epoch 149/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.2500
# Epoch 150/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2494
# Epoch 151/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2488
# Epoch 152/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.2481
# Epoch 153/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.2475
# Epoch 154/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.2469
# Epoch 155/200
# 100/100 [==============================] - 0s 34us/sample - loss: 5.2463
# Epoch 156/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2457
# Epoch 157/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.2451
# Epoch 158/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.2446
# Epoch 159/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2440
# Epoch 160/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.2434
# Epoch 161/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.2428
# Epoch 162/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.2423
# Epoch 163/200
# 100/100 [==============================] - 0s 10us/sample - loss: 5.2417
# Epoch 164/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2411
# Epoch 165/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2406
# Epoch 166/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.2400
# Epoch 167/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.2395
# Epoch 168/200
# 100/100 [==============================] - 0s 11us/sample - loss: 5.2390
# Epoch 169/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2384
# Epoch 170/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2379
# Epoch 171/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2374
# Epoch 172/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2368
# Epoch 173/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.2363
# Epoch 174/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2358
# Epoch 175/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2353
# Epoch 176/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.2347
# Epoch 177/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.2342
# Epoch 178/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.2337
# Epoch 179/200
# 100/100 [==============================] - 0s 14us/sample - loss: 5.2332
# Epoch 180/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.2327
# Epoch 181/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2322
# Epoch 182/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2317
# Epoch 183/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.2312
# Epoch 184/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.2307
# Epoch 185/200
# 100/100 [==============================] - 0s 16us/sample - loss: 5.2302
# Epoch 186/200
# 100/100 [==============================] - 0s 15us/sample - loss: 5.2297
# Epoch 187/200
# 100/100 [==============================] - 0s 12us/sample - loss: 5.2292
# Epoch 188/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.2287
# Epoch 189/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.2282
# Epoch 190/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2278
# Epoch 191/200
# 100/100 [==============================] - 0s 13us/sample - loss: 5.2273
# Epoch 192/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.2268
# Epoch 193/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.2263
# Epoch 194/200
# 100/100 [==============================] - 0s 22us/sample - loss: 5.2258
# Epoch 195/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.2254
# Epoch 196/200
# 100/100 [==============================] - 0s 20us/sample - loss: 5.2249
# Epoch 197/200
# 100/100 [==============================] - 0s 21us/sample - loss: 5.2244
# Epoch 198/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.2239
# Epoch 199/200
# 100/100 [==============================] - 0s 18us/sample - loss: 5.2235
# Epoch 200/200
# 100/100 [==============================] - 0s 17us/sample - loss: 5.2230

# %%
# plot all the networks we constructed

plt.plot(x, y, label='Truth')
for dim_to_consider, yhat in single_hidden_results.items():
    plt.plot(x, yhat, label=f'Hidden Dimension: {dim_to_consider}')
plt.title('Single Hidden Layer')
plt.legend()

# %% [markdown]
# ### PCA as a Linear Neural Network (Autoencoder)
#
# In this class, we covered Principal Component Analysis in which it was introduced as a **variance-maximization algorithm**: identify the direction of highest variance in your data (the first principal component), then remove this direction from your data, identify the direction of highest variance in your altered data (the second PC) and so on.
#
# ![](../img/pca.png)
#
# PCA can also be understood as a **data-reconstruction algorithm**, viewed in a linear neural network called an autoencoder. If you train a linear autoencoder with $K$ hidden units to reconstruct the input data, it will learn the subspace spanned by the top $K$ principal components.
#
# ![](../img/autoencoder.png)

# %% [markdown]
# ## Rylan's Experience as a Data Scientist
#
# Background
#     - Data Scientist at Uber
#     - Product Platform, Intelligent Decision Systems (IDS) Team
#
# Team dealt with three areas:
#
#     1. Time Series Forecasting:
#         - How many riders will request rides? How many drivers will be online to accept rides?
#         - For a new Uber user, how much profit should we expect for the next year?
#         - For Uber's data centers, how much compute and storage will be necessary in the next year?
#     2. Anomaly Detection
#         - Background: Uber uses a microservices architecture
#         - How can we define normal traffic/behavior for a service? How can we detect anomalies?
#         - In the event that some anomaly occurs, what is its root cause?
#     3. Ad Hoc Infrastructure Projects
#         - How can we monitor the freshness and quality of data used for modeling?
#         - Different databases have different financial and personnel costs. How can we optimize placement of data to minimize costs without impacting data scientists/analysts?
#         - Maintaining and searching documentation is slow and error prone. Can we create a chat bot to accelerate finding solutions for common queries?

# %% [markdown]
# How is your time typically allocated?
#
#     - Data is almost always messy, incomplete, erroneous, misleading, mixed, etc.
#     - Majority of time goes into Exploratory Data Analysis (EDA) and meetings to discuss data
#     - Maybe 5-10% of time is spent on modeling
#     - Data science is surprisingly social and collaborative
#
# What is the typical background of a data scientist?
#
#     - On my team of ~14, we had tremendously different backgrounds
#     - 1 string theory physicist
#     - 1 high energy experimental physicist
#     - 1 geography PhD with 10 years work experience as a research engineer/data scientist
#     - 1 medical imaging physicist / time series forecasting hobbyist
#     - 1 former software engineer, who made the switch after 4 years
#     - 1 bioinformatics PhD, public policy Master's
#     - 1 business analytics & finance Master's
#     - 1 statistics Master's with work experience in finance
#     - 1 industrial engineer with 20 years work experience as a software engineer/data scientist
#     - 1 astrophysicist
#     - 2 computer science Master's with work experience as software engineer/machine learning engineer
